# %%
# https://kalshi.com/market-data

# Import modules
import json
import requests
import pandas as pd
import numpy as np
import datetime

# Pull in one day of market data from https://kalshi.com/market-data
# Change date in URL as needed
URL = "https://kalshi-public-docs.s3.amazonaws.com/reporting/market_data_2022-05-15.json"
response = requests.get(URL)
jsondata = response.json()
data = json.dumps(jsondata)

# Convert JSON to dataframe
df = pd.DataFrame(eval(data))

# Write dataframe to CSV file in working directory
df.to_csv(r'./kalshi_all_markets_for_day.csv', sep=',', encoding='utf-8', header='true')

# %%
df['report_ticker'].unique()
# Out:
# array(['TURKEU', 'RECSS', 'CPTPP', 'MOON', 'MANCHIN', 'NETNEU', 'SCOTUSN',
#        'CARVMAK', 'CASE7DA', 'FED', 'ITAXH', 'CORPTAX', 'RECNC',
#        'APRPOTUS', 'NGDPQ', 'NGDP', 'SCOURT', 'GDPUSMIN', 'GDPUSMAX',
#        'VAROMIC', 'USICA', 'OSCARSUPACTR', 'OSCARSUPACTO', 'OSCARACTO',
#        'OSCARACTR', 'OSCARDIR', 'OSCARASPLAY', 'OSCARSPLAY', 'OSCARPIC',
#        'U3MIN', 'U3MAX', 'LCPIMIN', 'LCPIMAX', 'COVVC', 'GTEMP', 'SDEBT',
#        'EPOP', 'BBB', 'CPIEU', 'CPICN', 'GDPCN', 'GDPEU', 'GDPW',
#        'YINVERT', 'ACPI', 'VONCUK', 'GRAMAOTY', 'GRAMSOTY', 'GRAMBNA',
#        'GRAMROTY', 'TRDBAN', 'TECHREG', 'CASESURGE', 'CPI', 'GDP', 'OIL',
#        'NGAS', 'DAYLIGHT', 'GASTAX', 'RATEHIKE', 'CO2', 'SFFA', 'PROLLS',
#        'CASE7D', 'COVVOHC', 'CASE7DTX', 'CASE7DNYC', 'CASE7DNY',
#        'CASE7DFL', 'CASE7DCA', 'FORB', 'SOHN', 'CASE7DCN', 'TRAVELWARN',
#        'GAS', 'HOT100', 'CASEWCN', 'CASEW', 'TSAW', 'COOK', 'JEFFERSON',
#        'BEDOYA', 'RRF', 'COVIDBILL', 'MTA', 'TNOTE', 'EURO', 'LIZARRAGA',
#        'BARR', 'CHILDS', 'VAXX', 'BOOSTER', '538APPROVE', 'U3', 'RAINNYC',
#        'HIGHNY', 'HIGHCHI', 'RAINSEA', 'INX', 'CASED', 'NASDAQ100D',
#        'FRM', 'INXD', 'JOBLESS'], dtype=object)

# %%
df[df['report_ticker'] == 'INX']
# Out:
#            date        ticker_name report_ticker    payout_type  \
# 396  2022-05-15  INX-22MAY09-T4000           INX  Binary Option
# 397  2022-05-15  INX-22MAY09-B4025           INX  Binary Option
# 398  2022-05-15  INX-22MAY09-B4075           INX  Binary Option
# 399  2022-05-15  INX-22MAY09-B4125           INX  Binary Option
# 400  2022-05-15  INX-22MAY09-B4175           INX  Binary Option
# 401  2022-05-15  INX-22MAY09-B4225           INX  Binary Option
# 402  2022-05-15  INX-22MAY09-T4250           INX  Binary Option
# 420  2022-05-15  INX-22MAY10-T3900           INX  Binary Option
# 421  2022-05-15  INX-22MAY10-B3925           INX  Binary Option
# 422  2022-05-15  INX-22MAY10-B3975           INX  Binary Option
# 423  2022-05-15  INX-22MAY10-B4025           INX  Binary Option
# 424  2022-05-15  INX-22MAY10-B4075           INX  Binary Option
# 425  2022-05-15  INX-22MAY10-B4125           INX  Binary Option
# 426  2022-05-15  INX-22MAY10-B4175           INX  Binary Option
# 427  2022-05-15  INX-22MAY10-T4200           INX  Binary Option
# 472  2022-05-15  INX-22MAY13-T3900           INX  Binary Option
# 473  2022-05-15  INX-22MAY13-B3925           INX  Binary Option
# 474  2022-05-15  INX-22MAY13-B3975           INX  Binary Option
# 475  2022-05-15  INX-22MAY13-B4025           INX  Binary Option
# 476  2022-05-15  INX-22MAY13-B4075           INX  Binary Option
# 477  2022-05-15  INX-22MAY13-B4125           INX  Binary Option
# 478  2022-05-15  INX-22MAY13-B4175           INX  Binary Option
# 479  2022-05-15  INX-22MAY13-T4200           INX  Binary Option
# 493  2022-05-15  INX-22MAY11-T3850           INX  Binary Option
# 494  2022-05-15  INX-22MAY11-B3875           INX  Binary Option
# 495  2022-05-15  INX-22MAY11-B3925           INX  Binary Option
# 496  2022-05-15  INX-22MAY11-B3975           INX  Binary Option
# 497  2022-05-15  INX-22MAY11-B4025           INX  Binary Option
# 498  2022-05-15  INX-22MAY11-B4075           INX  Binary Option
# 499  2022-05-15  INX-22MAY11-B4125           INX  Binary Option
# 500  2022-05-15  INX-22MAY11-T4150           INX  Binary Option
#
#      open_interest  daily_volume  block_volume  high  low     status
# 396         6170.0             0             0    91   91  finalized
# 397         4521.0             0             0     1    1  finalized
# 398         5360.0             0             0     1    1  finalized
# 399         5181.0             0             0     3    3  finalized
# 400         8321.0             0             0     1    1  finalized
# 401         2352.0             0             0     2    2  finalized
# 402         2638.0             0             0     1    1  finalized
# 420         5235.0             0             0     1    1  finalized
# 421         5427.0             0             0     1    1  finalized
# 422         3059.0             0             0    10   10  finalized
# 423         2714.0             0             0    74   74  finalized
# 424         5514.0             0             0     1    1  finalized
# 425         8214.0             0             0     2    2  finalized
# 426         9808.0             0             0     3    3  finalized
# 427         8168.0             0             0     1    1  finalized
# 472         3847.0             0             0     1    1  finalized
# 473         6951.0             0             0     1    1  finalized
# 474         3575.0             0             0     1    1  finalized
# 475         5312.0             0             0    99   99  finalized
# 476         5055.0             0             0     2    2  finalized
# 477         3060.0             0             0     2    2  finalized
# 478         4894.0             0             0     4    4  finalized
# 479         2211.0             0             0     1    1  finalized
# 493         4407.0             0             0     1    1  finalized
# 494         8710.0             0             0     1    1  finalized
# 495         6361.0             0             0    99   99  finalized
# 496         3472.0             0             0     1    1  finalized
# 497         3534.0             0             0     1    1  finalized
# 498         3789.0             0             0     1    1  finalized
# 499         4659.0             0             0     1    1  finalized
# 500         6036.0             0             0     1    1  finalized
